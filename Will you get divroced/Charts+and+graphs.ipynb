# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# %%
marriage = pd.read_csv("marriage1.csv")
marriagemarriage1['everDivorced'].value_counts().plot(kind='pie',labels=['Never Divorced', 'Divorced'],colors=['#E7D7C1', '#BF4342'], figsize=(6, 6))
# Out:
#       Unnamed: 0  marriageStatus  everMarried  state  community  whichSpouse  \
# 0              0               1            0     36          2            2
# 1              1               1            0     24          2            1
# 2              2               1            0     44          2            1
# 3              3               3            0     39          1            0
# 4              4               2            2     12          2            0
# 5              5               5            0     45          2            0
# 6              6               1            0     51          3            1
# 7              7               1            0     47          1            2
# 8              8               3            0     18          3            0
# 9              9               5            0     47          1            0
# 10            10               1            0     36          1            1
# ...

# %%
#pie chart to show what kind of data about the marriage status we have showing over 60% of the data is about people who are married
#or divorced
marriage['marriageStatus'].value_counts().plot(kind='pie',labels=['Married','Divorced','Seperated','Living with a partner','Widowed'],figsize=(6, 6))

# %%
#number of people are very satisfied or mostly satisfied showing the data is of stable people
marriage['lifeSatisfaction'].value_counts().plot(kind='pie',labels=['Very Satisfied','mostly Satisfied','Mostly Disastified','Very Dissatisfied','Dont know'],figsize=(6, 6))

# %%
#education status of people with most people are high school graduate or technical grade i.e. 3 and 4
marriage['educationLevel'].value_counts().plot(kind='pie',figsize=(6, 6))

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(14,4))

for xcol, ax in zip(['marriageStatus', 'livedTogether', 'divorceViews'], axes):
    marriage.plot(kind='scatter', x=xcol, y='everMarried', ax=ax, alpha=0.5, color='r')

# %%
marriage1 = marriage[['lifeSatisfaction', 'everMarried']]

# %%
marriage1
# Out:
#       lifeSatisfaction  everMarried
# 0                    2            0
# 1                    2            0
# 2                    2            0
# 3                    2            0
# 4                    2            2
# 5                    1            0
# 6                    1            0
# 7                    1            0
# 8                    1            0
# 9                    2            0
# 10                   2            0
# 11                   2            0
# 12                   1            0
# 13                   2            0
# 14                   2            0
# 15                   2            2
# 16                   1            0
# 17                   2            0
# 18                   1            0
# 19                   1            1
# 20                   2            0
# 21                   2            0
# 22                   1            0
# 23                   1            0
# 24                   1            0
# ...

# %%
#checking the numbers for people who are satisfied and everMarried
#clearly people who are very satisfied have never been divorced are really high
marriage2 = marriage1.groupby(by=[marriage1.lifeSatisfaction,marriage1.everMarried, ])['lifeSatisfaction'].count()

# %%
marriage2.groupby(level=['everMarried', 'lifeSatisfaction']).sum()
# Out:
# everMarried  lifeSatisfaction
# 0            1                   741
#              2                   631
#              3                    50
#              4                    26
#              9                    46
# 1            1                    11
#              2                    19
#              4                     2
#              9                     1
# 2            1                    24
#              2                    38
#              3                     3
#              9                     2
# Name: lifeSatisfaction, dtype: int64

# %%
#Clearly people who are really satisfied with their marriage are never divorced or divorced only one time

marriage2.plot.bar()

# %%
marriage3 = marriage[['spouseEmployment', 'everMarried']]
marriage3
# Out:
#       spouseEmployment  everMarried
# 0                    1            0
# 1                    3            0
# 2                    9            0
# 3                    0            0
# 4                    0            2
# 5                    0            0
# 6                    2            0
# 7                    2            0
# 8                    0            0
# 9                    0            0
# 10                   1            0
# 11                   1            0
# 12                   1            0
# 13                   0            0
# 14                   0            0
# 15                   0            2
# 16                   1            0
# 17                   1            0
# 18                   1            0
# 19                   0            1
# 20                   3            0
# 21                   1            0
# 22                   1            0
# 23                   0            0
# 24                   2            0
# ...

# %%
marriage4 = marriage3.groupby(by=[marriage3.spouseEmployment,marriage3.everMarried, ])['everMarried'].count()
marriage4
# Out:
# spouseEmployment  everMarried
# 0                 0              481
#                   1               33
#                   2               67
# 1                 0              607
# 2                 0              111
# 3                 0              289
# 9                 0                6
# Name: everMarried, dtype: int64

# %%
marriage5 = marriage[['spouseEmployment', 'marriageStatus']]
marriage5
# Out:
#       spouseEmployment  marriageStatus
# 0                    1               1
# 1                    3               1
# 2                    9               1
# 3                    0               3
# 4                    0               2
# 5                    0               5
# 6                    2               1
# 7                    2               1
# 8                    0               3
# 9                    0               5
# 10                   1               1
# 11                   1               1
# 12                   1               1
# 13                   0               5
# 14                   0               5
# 15                   0               2
# 16                   1               1
# 17                   1               1
# 18                   1               1
# 19                   0               2
# 20                   3               1
# 21                   1               1
# 22                   1               1
# ...

# %%
#checking how spouse employement affects what kind of relation they have
#clearly whose spouse is full-time employement i.e. 1 in spouse employement are married

marriage5 = marriage5.groupby(by=[marriage5.spouseEmployment,marriage5.marriageStatus, ])['spouseEmployment'].count()
marriage5
# Out:
# spouseEmployment  marriageStatus
# 0                 2                 100
#                   3                 215
#                   4                  64
#                   5                 202
# 1                 1                 607
# 2                 1                 111
# 3                 1                 289
# 9                 1                   6
# Name: spouseEmployment, dtype: int64

# %%
#people who are full-time employed i.e. 1 are already married and not divorced 
marriage5.plot.bar()

# %%
marriage6 = marriage[['ownrent', 'everMarried']]
marriage6
# Out:
#       ownrent  everMarried
# 0           1            0
# 1           1            0
# 2           1            0
# 3           1            0
# 4           1            2
# 5           1            0
# 6           1            0
# 7           1            0
# 8           1            0
# 9           1            0
# 10          1            0
# 11          1            0
# 12          1            0
# 13          1            0
# 14          1            0
# 15          1            2
# 16          1            0
# 17          1            0
# 18          1            0
# 19          1            1
# 20          1            0
# 21          1            0
# 22          1            0
# 23          1            0
# 24          1            0
# 25          2            0
# 26          2            2
# 27          1            0
# 28          1            0
# 29          1            0
# ...       ...          ...
# 1564        2            0
# 1565        2            0
# ...

# %%
#number are highest for poeple who own the house i.e. ownrent=1 are never getting divorced once 

marriage6 = marriage6.groupby(by=[marriage6.ownrent,marriage6.everMarried, ])['ownrent'].count()
marriage6
# Out:
# ownrent  everMarried
# 1        0              1083
#          1                20
#          2                29
# 2        0               372
#          1                12
#          2                35
# 3        0                36
#          1                 1
#          2                 3
# 9        0                 3
# Name: ownrent, dtype: int64

# %%
marriage6.plot.bar()
